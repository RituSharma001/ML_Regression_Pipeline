# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### EDA

# %%
df=pd.read_csv("MyData\employ.csv")

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df["Department"].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df["salary"].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df["left"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df["Work_accident"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
df["satisfaction_level"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %% [markdown]
# Statistical Analysis

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_9316\3235002301.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# Time spent on compney makes higher effect on employ Retention.(Plot chart on left and time_spend_compeny).

# %% [markdown]
# ## This heat map showes the factor who make highest effect on employ retention is how much the emloy time spent on compney
# ## 1. if a person spent moer then 6 hours in compeny probabality of he lefts the compeny is very high

# %%
# Extract the data for plotting
categories = df['left']
values = df['time_spend_company']

# Create a bar chart
plt.bar(df["left"], df["time_spend_company"])
plt.xlabel('left')
plt.ylabel('time_spend_company')
plt.title('Bar Chart Between left and time_spend_company')
plt.show()

# %% [markdown]
# ##

# %%
import matplotlib.pyplot as plt
import pandas as pd


x_values = df['left']
y_values = df['time_spend_company']

plt.scatter(x_values, y_values, marker='o', color='blue', label='Scatter Plot')
plt.xlabel('left')
plt.ylabel('time_spend_company')
plt.title('Scatter Plot of left vs time_spend_company')
plt.legend()
plt.grid(True)  # Add grid lines
plt.show()
